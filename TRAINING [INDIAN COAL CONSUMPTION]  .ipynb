# %%
import pandas as pd

# %%
df = pd.read_csv('Coal Consumption data.csv')
df
# Out:
#         srcStateName  srcYear Types of coal      Coal Consuming Sectors  \
# 0              DELHI     2011      RAW COAL                       OTHER
# 1             PUNJAB     2011      RAW COAL             POWER (UTILITY)
# 2     ANDHRA PRADESH     2011      RAW COAL             POWER (CAPTIVE)
# 3              ASSAM     2011      RAW COAL                PULP & PAPER
# 4             PUNJAB     2011      RAW COAL                 FERTILISERS
# ...              ...      ...           ...                         ...
# 1952       TAMILNADU     2020       LIGNITE                      BRICKS
# 1953          OTHERS     2020      RAW COAL                       OTHER
# 1954          ODISHA     2020      RAW COAL  COLLIERY OWN - CONSUMPTION
# 1955     WEST BENGAL     2020      RAW COAL                       OTHER
# 1956          ODISHA     2020      RAW COAL                PULP & PAPER
#
#       Coal Consumed  YearCode                              Year
# ...

# %%
df.head()
# Out:
#      srcStateName  srcYear Types of coal Coal Consuming Sectors  \
# 0           DELHI     2011      RAW COAL                  OTHER
# 1          PUNJAB     2011      RAW COAL        POWER (UTILITY)
# 2  ANDHRA PRADESH     2011      RAW COAL        POWER (CAPTIVE)
# 3           ASSAM     2011      RAW COAL           PULP & PAPER
# 4          PUNJAB     2011      RAW COAL            FERTILISERS
#
#    Coal Consumed  YearCode                              Year
# 0          0.131      2011  Financial Year (Apr - Mar), 2011
# 1         12.545      2011  Financial Year (Apr - Mar), 2011
# 2          3.363      2011  Financial Year (Apr - Mar), 2011
# 3          0.095      2011  Financial Year (Apr - Mar), 2011
# 4          1.111      2011  Financial Year (Apr - Mar), 2011

# %%
df.tail()
# Out:
#      srcStateName  srcYear Types of coal      Coal Consuming Sectors  \
# 1952    TAMILNADU     2020       LIGNITE                      BRICKS
# 1953       OTHERS     2020      RAW COAL                       OTHER
# 1954       ODISHA     2020      RAW COAL  COLLIERY OWN - CONSUMPTION
# 1955  WEST BENGAL     2020      RAW COAL                       OTHER
# 1956       ODISHA     2020      RAW COAL                PULP & PAPER
#
#       Coal Consumed  YearCode                              Year
# 1952          0.011      2020  Financial Year (Apr - Mar), 2020
# 1953          3.232      2020  Financial Year (Apr - Mar), 2020
# 1954          0.002      2020  Financial Year (Apr - Mar), 2020
# 1955          1.750      2020  Financial Year (Apr - Mar), 2020
# 1956          0.117      2020  Financial Year (Apr - Mar), 2020

# %%
df.sample(6)
# Out:
#      srcStateName  srcYear Types of coal Coal Consuming Sectors  \
# 1701    JHARKHAND     2019      RAW COAL        STEEL (BOILERS)
# 337     RAJASTHAN     2012       LIGNITE                 BRICKS
# 278   WEST BENGAL     2012      RAW COAL               CHEMICAL
# 183        ODISHA     2011      RAW COAL            SPONGE IRON
# 1521        ASSAM     2018      RAW COAL                 CEMENT
# 427     KARNATAKA     2013      RAW COAL      TEXTILES & RAYONS
#
#       Coal Consumed  YearCode                              Year
# 1701          0.248      2019  Financial Year (Apr - Mar), 2019
# 337           0.053      2012  Financial Year (Apr - Mar), 2012
# 278           0.011      2012  Financial Year (Apr - Mar), 2012
# 183           4.842      2011  Financial Year (Apr - Mar), 2011
# 1521          0.027      2018  Financial Year (Apr - Mar), 2018
# 427           0.150      2013  Financial Year (Apr - Mar), 2013

# %%
df.shape
# Out:
# (1957, 7)

# %%
df.size
# Out:
# 13699

# %%
df.info
# Out:
# <bound method DataFrame.info of         srcStateName  srcYear Types of coal      Coal Consuming Sectors  \
# 0              DELHI     2011      RAW COAL                       OTHER
# 1             PUNJAB     2011      RAW COAL             POWER (UTILITY)
# 2     ANDHRA PRADESH     2011      RAW COAL             POWER (CAPTIVE)
# 3              ASSAM     2011      RAW COAL                PULP & PAPER
# 4             PUNJAB     2011      RAW COAL                 FERTILISERS
# ...              ...      ...           ...                         ...
# 1952       TAMILNADU     2020       LIGNITE                      BRICKS
# 1953          OTHERS     2020      RAW COAL                       OTHER
# 1954          ODISHA     2020      RAW COAL  COLLIERY OWN - CONSUMPTION
# 1955     WEST BENGAL     2020      RAW COAL                       OTHER
# 1956          ODISHA     2020      RAW COAL                PULP & PAPER
#
#       Coal Consumed  YearCode                              Year
# ...

# %%
df.describe()
# Out:
#            srcYear  Coal Consumed     YearCode
# count  1957.000000    1957.000000  1957.000000
# mean   2015.376086       3.387410  2015.376086
# std       2.822202       9.495445     2.822202
# min    2011.000000       0.000000  2011.000000
# 25%    2013.000000       0.035000  2013.000000
# 50%    2015.000000       0.214000  2015.000000
# 75%    2018.000000       1.340000  2018.000000
# max    2020.000000      79.342000  2020.000000

# %%
variables_missing_value = df.isnull().sum()
variables_missing_value
# Out:
# srcStateName              0
# srcYear                   0
# Types of coal             0
# Coal Consuming Sectors    0
# Coal Consumed             0
# YearCode                  0
# Year                      0
# dtype: int64

# %%
Quantiy_have_missing_value = df['Coal Consuming Sectors'].isnull().sum() > 0
Quantiy_have_missing_value
# Out:
# False

# %%
df.dropna().head()
# Out:
#      srcStateName  srcYear Types of coal Coal Consuming Sectors  \
# 0           DELHI     2011      RAW COAL                  OTHER
# 1          PUNJAB     2011      RAW COAL        POWER (UTILITY)
# 2  ANDHRA PRADESH     2011      RAW COAL        POWER (CAPTIVE)
# 3           ASSAM     2011      RAW COAL           PULP & PAPER
# 4          PUNJAB     2011      RAW COAL            FERTILISERS
#
#    Coal Consumed  YearCode                              Year
# 0          0.131      2011  Financial Year (Apr - Mar), 2011
# 1         12.545      2011  Financial Year (Apr - Mar), 2011
# 2          3.363      2011  Financial Year (Apr - Mar), 2011
# 3          0.095      2011  Financial Year (Apr - Mar), 2011
# 4          1.111      2011  Financial Year (Apr - Mar), 2011

# %%
df1=df['Coal Consuming Sectors'].value_counts()
df1.head()
# Out:
# Coal Consuming Sectors
# POWER (UTILITY)    305
# OTHER              285
# POWER (CAPTIVE)    255
# CEMENT             216
# PULP & PAPER       145
# Name: count, dtype: int64

# %%
value_numbers = df['Coal Consumed'].value_counts()
value_numbers.head(10)
# Out:
# Coal Consumed
# 0.001    40
# 0.004    40
# 0.000    30
# 0.002    26
# 0.008    21
# 0.003    21
# 0.012    18
# 0.005    18
# 0.011    18
# 0.023    16
# Name: count, dtype: int64

# %% [markdown]
# # COAL CONSUMPTION WITH GRAPHS

# %%
df.head(10)
# Out:
#      srcStateName  srcYear Types of coal Coal Consuming Sectors  \
# 0           DELHI     2011      RAW COAL                  OTHER
# 1          PUNJAB     2011      RAW COAL        POWER (UTILITY)
# 2  ANDHRA PRADESH     2011      RAW COAL        POWER (CAPTIVE)
# 3           ASSAM     2011      RAW COAL           PULP & PAPER
# 4          PUNJAB     2011      RAW COAL            FERTILISERS
# 5           DELHI     2011   WASHED COAL        POWER (UTILITY)
# 6     WEST BENGAL     2011     MIDDLINGS        POWER (CAPTIVE)
# 7       KARNATAKA     2011   WASHED COAL                 CEMENT
# 8  ANDHRA PRADESH     2011      RAW COAL        STEEL (BOILERS)
# 9     MAHARASHTRA     2011      RAW COAL        POWER (UTILITY)
#
#    Coal Consumed  YearCode                              Year
# 0          0.131      2011  Financial Year (Apr - Mar), 2011
# 1         12.545      2011  Financial Year (Apr - Mar), 2011
# 2          3.363      2011  Financial Year (Apr - Mar), 2011
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.array(['RAW COAL','RAW COAL','RAW COAL','RAW COAL','RAW COAL','WASHED COAL','MIDDLINGS','WASHED COAL','RAW COAL','RAW COAL'])
y = np.array([0.131,12.545,3.363,0.095,1.111,1.599,0.462,0.045,0.121,34.997])
plt.title("Indian Coal Consumption")
plt.xlabel("Types of coal")
plt.ylabel("Coal Consumed")
plt.plot(x, y)
plt.grid()
plt.show()

# %%
plt.scatter(df['Coal Consuming Sectors'], df['YearCode'])
plt.title("Coal Consumption")
plt.xlabel('Coal Consuming Sectors')
plt.ylabel('YearCode')
plt.show()

# %%
df = pd.DataFrame({
'src StateName': ['DELHI', 'PUNJAB', 'ANDHRA PRADESH', 'ASSAM', 'PUNJAB', 'DELHI', 'WEST BENGAL', 'KARNATAKA', 'ANDHRA PRADESH', 'MAHARASHTRA'],
'srcYear': [2011, 2011, 2011, 2011, 2011, 2011, 2011, 2011, 2011, 2011],
'Types of coal': ['RAW COAL', 'RAW COAL', 'RAW COAL', 'RAW COAL', 'RAW COAL', 'WASHED COAL', 'MIDDLINGS', 'WASHED COAL', 'RAW COAL', 'RAW COAL'],
'Coal Consuming Sectors': ['OTHER', 'POWER (UTILITY)', 'POWER (CAPTIVE)', 'PULP & PAPER', 'FERTILISERS', 'POWER (UTILITY)', 'POWER (CAPTIVE)', 'CEMENT', 'STEEL (BOILERS)', 'POWER (UTILITY)'],
'Coal Consumed': [0.131, 12.545, 3.363, 0.095, 1.111, 1.599, 0.462, 0.045, 0.121, 34.997],
'YearCode': ['2011', '2011', '2011', '2011', '2011', '2011', '2011', '2011', '2011', '2011']
})

plt.figure(figsize=(10, 6))
plt.scatter(df['YearCode'], df['Coal Consumed'], c='blue', alpha=0.7)
plt.xlabel('Financial Year (YearCode)')
plt.ylabel('Coal Consumed')
plt.title('Coal Consumed by Different Sectors Across Financial Years')
plt.grid(True)
plt.show()

# %%
x = np.array(['RAW COAL','RAW COAL','RAW COAL','RAW COAL','RAW COAL','WASHED COAL','MIDDLINGS','WASHED COAL','RAW COAL','RAW COAL'])
y = np.array([0.131,12.545,3.363,0.095,1.111,1.599,0.462,0.045,0.121,34.997])
plt.xlabel('Types of coal')
plt.ylabel('Coal Consumed')
plt.scatter(x, y)
plt.show()

# %%
plt.barh(df['Coal Consuming Sectors'], df['Coal Consumed'],color = "red")
plt.title("Coal Comsumption",color = 'blue')
plt.xlabel('Coal Consuming Sectors')
plt.ylabel('Coal Consumed')
plt.show()

# %%
coal_sectors = ['OTHER', 'POWER (UTILITY)', 'POWER (CAPTIVE)', 'PULP & PAPER', 'FERTILISERS', 'CEMENT']
coal_consumption = [0.131, 12.545, 3.363, 0.095, 1.111, 0.045,]
plt.barh(coal_sectors, coal_consumption, color='skyblue')
plt.xlabel('Coal Consumed (in tons)') 
plt.ylabel('Coal Consuming Sectors')
plt.title('Coal Consumption by Sectors')
plt.gca().invert_yaxis() 
plt.grid(axis='x', linestyle='--', alpha=0.6)
plt.tight_layout()
plt.show()

# %%
plt.hist(df['Coal Consumed'],color = "pink")
plt.title("Coal Comsumption",color = 'blue')
plt.xlabel('Coal Consuming Sectors')
plt.ylabel('Coal Consumed')
plt.show()

# %%
df.hist(grid=True)
plt.title("Indian Coal Consumption")
plt.show()

# %%
import seaborn as sns

# %%
data = {'StateName': ['DELHI', 'PUNJAB', 'ANDHRA PRADESH', 'ASSAM', 'PUNJAB', 'DELHI', 'WEST BENGAL', 'KARNATAKA', 'ANDHRA PRADESH', 'MAHARASHTRA'],
        'Coal Consuming Sectors': ['OTHER', 'POWER (UTILITY)', 'POWER (CAPTIVE)', 'PULP & PAPER', 'FERTILISERS', 'POWER (UTILITY)', 'POWER (CAPTIVE)', 'CEMENT', 'STEEL (BOILERS)', 'POWER (UTILITY)'],
        'Coal Consumed': [0.131, 12.545, 3.363, 0.095, 1.111, 1.599, 0.462, 0.045, 0.121, 34.997]}
df = pd.DataFrame(data)
sns.scatterplot(x = "Coal Consuming Sectors", y = "Coal Consumed", data=df,color = 'brown')
plt.xticks(rotation=45)
plt.show()

# %%
coal_consumed = [10, 15, 8, 12, 9, 25, 6, 18, 11, 7]

plt.boxplot(coal_consumed)
plt.xlabel('Coal Consumed')
plt.ylabel('Amount')
plt.title('Distribution of Coal Consumed')
plt.show()

# %%
coal_consumption = {'OTHER': 0.131, 'POWER (UTILITY)': 48.542, 'POWER (CAPTIVE)': 3.825, 'PULP & PAPER': 0.095, 'FERTILISERS': 1.111, 'CEMENT': 0.045, 'STEEL (BOILERS)': 0.121}

pie_chart_slice_labels = coal_consumption.keys()

pie_chart_slice_values = coal_consumption.values()
plt.pie(pie_chart_slice_values, labels=pie_chart_slice_labels)
plt.title("Pie Chart of Coal Consumption by Sector")
plt.show()

# %%
data = {'StateName': ['DELHI', 'PUNJAB', 'ANDHRA PRADESH', 'ASSAM', 'PUNJAB', 'DELHI', 'WEST BENGAL', 'KARNATAKA', 'ANDHRA PRADESH', 'MAHARASHTRA'],
        'Coal Consuming Sectors': ['OTHER', 'POWER (UTILITY)', 'POWER (CAPTIVE)', 'PULP & PAPER', 'FERTILISERS', 'POWER (UTILITY)', 'POWER (CAPTIVE)', 'CEMENT', 'STEEL (BOILERS)', 'POWER (UTILITY)']}
df = pd.DataFrame(data)
sns.countplot(x = "StateName", data=df)
plt.xticks(rotation=45) 
plt.show()

# %%
sectors = ['POWER (UTILITY)', 'POWER (CAPTIVE)', 'PULP & PAPER', 'FERTILISERS', 'CEMENT', 'STEEL (BOILERS)']
coal_consumption = [48.542, 3.825, 0.095, 1.111, 0.045, 0.121] 
plt.bar(sectors, coal_consumption)
plt.xlabel('Coal Consuming Sectors')
plt.ylabel('Coal Consumed (in million tonnes)') 
plt.title('Coal Consumption by Sector in India')
plt.xticks(rotation=45) 
plt.show()

# %%
data = {'StateName': ['DELHI', 'PUNJAB', 'ANDHRA PRADESH', 'ASSAM', 'PUNJAB', 'DELHI', 'WEST BENGAL', 'KARNATAKA', 'ANDHRA PRADESH', 'MAHARASHTRA'],
        'Types of Coal': [1, 1, 1, 1, 1, 2, 3, 3, 1, 1],  # Assuming numerical data for types of coal
        'Coal Consumed': [0.131, 12.545, 3.363, 0.095, 1.111, 1.599, 0.462, 0.045, 0.121, 34.997]}

df = pd.DataFrame(data)
sns.pairplot(df)
plt.show()
# Out:
# C:\Users\HP\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
coal_consumed_per_sector = [10, 15, 8, 12, 9, 25, 6, 18, 11, 7]
plt.hist(coal_consumed_per_sector,color = 'skyblue')
plt.xlabel('Coal Consumed')
plt.ylabel('Number of Sectors')
plt.title('Distribution of Coal Consumed per Sector')
plt.show()

# %%
data = {'Coal Consumed (ton)': [10, 15, 8, 12, 9, 25, 6, 18, 11, 7],
        'Price per ton (USD)': [20, 30, 25, 32, 28, 35, 22, 38, 29, 24]}
df = pd.DataFrame(data)
sns.jointplot(x = "Coal Consumed (ton)", y = "Price per ton (USD)", data=df)
plt.show()
